# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/1f/d9/74017c4eec7a28892d8d6e31ae9de3baef71f5a5286e74e6b7aad7f8c837/pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/81/c4/34e93fe5f5429d7570ec1fa436f1986fb1f00c3e0f43a589fe2bbcd22c3f/pytz-2025.2-py2.py3-none-any.whl.metadata
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/5c/23/c7abc0ca0a1526a0774eca151daeb8de62ec457e77262b66b359c3c7679e/tzdata-2025.2-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB 660.6 kB/s eta 0:00:17
#    - -------------------------------------- 0.5/11.0 MB 6.6 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.0 MB 9.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.0 MB 8.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.0 MB 8.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.0 MB 7.8 MB/s eta 0:00:02
#    -------- ------------------------------- 2.3/11.0 MB 7.3 MB/s eta 0:00:02
#    --------- ------------------------------ 2.5/11.0 MB 6.9 MB/s eta 0:00:02
#    --------- ------------------------------ 2.7/11.0 MB 6.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.9/11.0 MB 6.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.1/11.0 MB 6.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 6.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.6/11.0 MB 6.1 MB/s eta 0:00:02
#    ------------- -------------------------- 3.6/11.0 MB 6.1 MB/s eta 0:00:02
#    --------------- ------------------------ 4.2/11.0 MB 6.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.4/11.0 MB 6.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.6/11.0 MB 5.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 4.9/11.0 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.3/11.0 MB 6.0 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 6.0 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/11.0 MB 6.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.2/11.0 MB 5.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.5/11.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------ --------------- 6.8/11.0 MB 5.9 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 5.9 MB/s eta 0:00:01
#    --------------------------- ------------ 7.4/11.0 MB 5.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.8/11.0 MB 6.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.6/11.0 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 9.0/11.0 MB 6.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.5/11.0 MB 6.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 9.9/11.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 10.1/11.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.0 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  10.9/11.0 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 5.5 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    ---------------------------- ----------- 368.6/509.2 kB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 509.2/509.2 kB 6.4 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    ------------------------------------- - 337.9/347.8 kB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 347.8/347.8 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.3.0 pytz-2025.2 tzdata-2025.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv("C:/Users/PRAJYOT UPADHYE/Downloads/placement.csv")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df=df.iloc[:,1:]

# %%
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlibNote: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'c:\Users\PRAJYOT UPADHYE\AppData\Local\Programs\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/b1/79/0d1c165eac44405a86478082e225fce87874f7198300bbebc55faaf6d28d/matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/01/c8/fadd0b92ffa7b5eb5949bf340a63a4a496a6930a6c37a7ba0f12acb076d6/contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata
#   Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/46/e6/fe50183b1a0e1018e7487ee740fa8bb127b9f5075a41e20d017201e8ab14/fonttools-4.58.4-cp312-cp312-win_amd64.whl.metadata
#   Downloading fonttools-4.58.4-cp312-cp312-win_amd64.whl.metadata (108 kB)
#      ---------------------------------------- 0.0/108.7 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/108.7 kB 435.7 kB/s eta 0:00:01
#      --------------------------- --------- 81.9/108.7 kB 762.6 kB/s eta 0:00:01
#      ------------------------------------ 108.7/108.7 kB 903.7 kB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/bd/72/dfff0cc97f2a0776e1c9eb5bef1ddfd45f46246c6533b0191887a427bca5/kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/7c/18/24bff2ad716257fc03da964c5e8f05d9790a779a8895d6566e493ccf0189/pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata
#   Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl.metadata (9.1 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/05/e7/df2285f3d08fee213f2d041540fa4fc9ca6c2d44cf36d3a035bf2a8d2bcc/pyparsing-3.2.3-py3-none-any.whl.metadata
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/8.1 MB 4.3 MB/s eta 0:00:02
#    - -------------------------------------- 0.3/8.1 MB 3.5 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/8.1 MB 3.8 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.1 MB 3.5 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.8/8.1 MB 3.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.1 MB 3.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.1 MB 3.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.4/8.1 MB 3.9 MB/s eta 0:00:02
#    -------- ------------------------------- 1.6/8.1 MB 4.0 MB/s eta 0:00:02
#    --------- ------------------------------ 1.8/8.1 MB 4.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 4.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.3/8.1 MB 4.2 MB/s eta 0:00:02
#    ------------ --------------------------- 2.5/8.1 MB 4.2 MB/s eta 0:00:02
#    ------------- -------------------------- 2.7/8.1 MB 4.2 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 4.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.4/8.1 MB 4.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.5/8.1 MB 4.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 4.7 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/8.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.1 MB 5.0 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 5.2 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 5.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 5.9/8.1 MB 5.6 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 5.7 MB/s eta 0:00:01
#    -------------------------------- ------- 6.6/8.1 MB 5.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 5.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.4/8.1 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 6.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp312-cp312-win_amd64.whl (223 kB)
#    ---------------------------------------- 0.0/223.0 kB ? eta -:--:--
#    --------------------------------------- 223.0/223.0 kB 14.2 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.2 MB 17.3 MB/s eta 0:00:01
#    -------------------- ------------------- 1.2/2.2 MB 12.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.2 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 7.9 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
#    ---------------------------------------- 0.0/71.9 kB ? eta -:--:--
#    ---------------------------------------- 71.9/71.9 kB 4.1 MB/s eta 0:00:00
# Downloading pillow-11.2.1-cp312-cp312-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --------- ------------------------------ 0.6/2.7 MB 12.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.1/2.7 MB 11.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.0/2.7 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  2.7/2.7 MB 15.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 13.1 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#    ---------------------------------------- 0.0/111.1 kB ? eta -:--:--
#    ---------------------------------------- 111.1/111.1 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.58.4 kiwisolver-1.4.8 matplotlib-3.10.3 pillow-11.2.1 pyparsing-3.2.3

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
# %pip install sklearn.model
# Out:
# Collecting sklearn.modelNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for sklearn.model from https://files.pythonhosted.org/packages/f5/1c/c19ea6ef27d4dffaaf0d629a451e29c04be753214e1fbed453efc35757df/sklearn_model-0.0.6-py3-none-any.whl.metadata
#   Downloading sklearn_model-0.0.6-py3-none-any.whl.metadata (2.7 kB)
# Collecting scikit-learn>=0.22 (from sklearn.model)
#   Obtaining dependency information for scikit-learn>=0.22 from https://files.pythonhosted.org/packages/68/c7/4e956281a077f4835458c3f9656c666300282d5199039f26d9de1dabd9be/scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata
#   Downloading scikit_learn-1.7.0-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: pandas in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from sklearn.model) (2.3.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.22->sklearn.model) (2.3.0)
# Collecting scipy>=1.8.0 (from scikit-learn>=0.22->sklearn.model)
#   Obtaining dependency information for scipy>=1.8.0 from https://files.pythonhosted.org/packages/e6/eb/3bf6ea8ab7f1503dca3a10df2e4b9c3f6b3316df07f6c0ded94b281c7101/scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata
#   Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------- ------------ 41.0/60.8 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 463.5 kB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn>=0.22->sklearn.model)
#   Obtaining dependency information for joblib>=1.2.0 from https://files.pythonhosted.org/packages/7d/4f/1195bbac8e0c2acc5f740661631d8d750dc38d4a32b23ee5df3cde6f4e0d/joblib-1.5.1-py3-none-any.whl.metadata
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=0.22->sklearn.model)
#   Obtaining dependency information for threadpoolctl>=3.1.0 from https://files.pythonhosted.org/packages/32/d5/f9a850d79b0851d1d4ef6456097579a9005b31fea68726a4ae5f2d82ddd9/threadpoolctl-3.6.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from pandas->sklearn.model) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from pandas->sklearn.model) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from pandas->sklearn.model) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->sklearn.model) (1.16.0)
# Downloading sklearn_model-0.0.6-py3-none-any.whl (6.6 kB)
# Downloading scikit_learn-1.7.0-cp312-cp312-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#     --------------------------------------- 0.2/10.7 MB 7.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/10.7 MB 9.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/10.7 MB 8.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/10.7 MB 8.8 MB/s eta 0:00:02
#    ------- -------------------------------- 1.9/10.7 MB 8.6 MB/s eta 0:00:02
#    --------- ------------------------------ 2.4/10.7 MB 9.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.0/10.7 MB 9.6 MB/s eta 0:00:01
#    ------------- -------------------------- 3.5/10.7 MB 9.7 MB/s eta 0:00:01
#    --------------- ------------------------ 4.2/10.7 MB 10.2 MB/s eta 0:00:01
#    ------------------ --------------------- 4.8/10.7 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 5.3/10.7 MB 10.5 MB/s eta 0:00:01
#    --------------------- ------------------ 5.8/10.7 MB 10.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.3/10.7 MB 10.5 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.7 MB 10.9 MB/s eta 0:00:01
#    -------------------------- ------------- 7.0/10.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.5/10.7 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.3/10.7 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.0/10.7 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.7 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  10.7/10.7 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 11.7 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.7 kB ? eta -:--:--
#    ---------------------------------------- 307.7/307.7 kB 9.3 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#     --------------------------------------- 1.0/41.0 MB 20.7 MB/s eta 0:00:02
#    - -------------------------------------- 1.9/41.0 MB 24.5 MB/s eta 0:00:02
#    -- ------------------------------------- 2.7/41.0 MB 19.2 MB/s eta 0:00:02
#    --- ------------------------------------ 3.9/41.0 MB 22.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.0/41.0 MB 21.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.3/41.0 MB 18.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.1/41.0 MB 18.5 MB/s eta 0:00:02
#    ------ --------------------------------- 6.8/41.0 MB 18.0 MB/s eta 0:00:02
#    ------- -------------------------------- 7.6/41.0 MB 18.1 MB/s eta 0:00:02
#    -------- ------------------------------- 8.6/41.0 MB 18.3 MB/s eta 0:00:02
#    -------- ------------------------------- 9.2/41.0 MB 18.9 MB/s eta 0:00:02
#    --------- ------------------------------ 10.1/41.0 MB 17.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 11.9/41.0 MB 19.3 MB/s eta 0:00:02
#    ------------ --------------------------- 12.9/41.0 MB 19.9 MB/s eta 0:00:02
#    ------------- -------------------------- 14.3/41.0 MB 19.8 MB/s eta 0:00:02
#    -------------- ------------------------- 15.3/41.0 MB 20.5 MB/s eta 0:00:02
#    -------------- ------------------------- 15.3/41.0 MB 20.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.5/41.0 MB 22.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 18.2/41.0 MB 21.8 MB/s eta 0:00:02
#    ------------------ --------------------- 19.4/41.0 MB 27.3 MB/s eta 0:00:01
#    ------------------ --------------------- 19.4/41.0 MB 27.3 MB/s eta 0:00:01
#    ------------------ --------------------- 19.4/41.0 MB 27.3 MB/s eta 0:00:01
#    ------------------- -------------------- 19.8/41.0 MB 19.9 MB/s eta 0:00:02
#    -------------------- ------------------- 21.0/41.0 MB 18.7 MB/s eta 0:00:02
#    --------------------- ------------------ 22.2/41.0 MB 18.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.8/41.0 MB 18.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 24.4/41.0 MB 18.7 MB/s eta 0:00:01
#    ------------------------ --------------- 24.9/41.0 MB 17.3 MB/s eta 0:00:01
#    --------------------------- ------------ 27.7/41.0 MB 20.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.5/41.0 MB 21.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.2/41.0 MB 29.8 MB/s eta 0:00:01
#    ------------------------------ --------- 31.6/41.0 MB 28.5 MB/s eta 0:00:01
#    -------------------------------- ------- 33.3/41.0 MB 29.7 MB/s eta 0:00:01
#    --------------------------------- ------ 34.8/41.0 MB 36.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.6/41.0 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------- -- 38.0/41.0 MB 32.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.2/41.0 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  40.4/41.0 MB 31.1 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 32.8 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 14.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn.model
# Successfully installed joblib-1.5.1 scikit-learn-1.7.0 scipy-1.15.3 sklearn.model-0.0.6 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 82   6.5   37.0
# 55   7.8  114.0
# 43   6.8  141.0
# 59   4.8  112.0
# 3    7.4  132.0
# ..   ...    ...
# 7    5.0   63.0
# 54   6.4  141.0
# 18   4.0  100.0
# 32   7.0  139.0
# 47   5.2  161.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 5    7.1   48.0
# 23   4.7   87.0
# 42   7.6   89.0
# 14   6.1  103.0
# 49   5.4  135.0
# 17   3.3  183.0
# 26   7.0  199.0
# 90   7.3   86.0
# 88   4.4  149.0
# 58   8.0   79.0

# %%
y_train
# Out:
# 35    1
# 10    1
# 95    0
# 46    0
# 56    0
#      ..
# 64    1
# 86    0
# 6     0
# 78    0
# 74    1
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 91    1
# 85    1
# 38    1
# 34    0
# 44    1
# 79    1
# 66    1
# 97    1
# 69    1
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.77573677, -0.81394408],
#        [ 0.06423298, -1.9479219 ],
#        [-1.44771257,  1.9580017 ],
#        [-0.55833283, -0.20915591],
#        [ 0.15317095, -1.44393176],
#        [-0.82514675, -1.49433077],
#        [-0.64727081, -0.30995394],
#        [ 0.59786082, -0.05795887],
#        [ 1.22042664,  0.37043275],
#        [-1.09196068, -0.8895426 ],
#        [ 1.6651165 , -0.20915591],
#        [-1.3587746 , -2.02352042],
#        [ 0.86467474,  0.42083177],
#        [-1.18089865,  0.59722832],
#        [ 1.39830258,  0.1940362 ],
#        [-0.46939486,  0.32003374],
#        [-0.02470499, -0.41075197],
#        [-0.91408473,  0.72322585],
#        [ 2.10980637,  1.15161748],
#        [-0.55833283, -0.03275936],
#        [-1.3587746 ,  0.67282684],
#        [-0.46939486, -0.38555246],
#        [-0.64727081,  2.56278987],
#        [ 0.50892285,  0.1940362 ],
#        [ 1.22042664, -1.82192436],
#        [ 0.50892285, -2.14951796],
#        [-0.91408473,  0.29483423],
#        [-0.46939486,  0.42083177],
#        [ 1.22042664, -0.15875689],
#        [ 1.93193043,  0.67282684],
#        [-0.82514675, -0.78874457],
#        [ 1.04255069, -1.87232338],
#        [-0.11364297,  0.49643029],
#        [ 0.24210893, -0.23435542],
#        [ 0.95361272,  1.9328022 ],
#        [ 0.3310469 ,  0.11843768],
#        [-0.64727081,  0.97522093],
#        [ 0.86467474,  0.39563226],
#        [-1.0030227 , -0.25955492],
#        [-2.3370923 ,  1.52961008],
#        [-0.91408473, -0.05795887],
#        [ 0.06423298,  0.04283916],
#        [ 0.95361272, -0.25955492],
#        [ 0.06423298, -1.41873225],
#        [ 0.06423298, -0.51154999],
#        [-0.20258094,  1.17681698],
#        [ 0.77573677,  0.47123078],
#        [ 0.95361272,  0.42083177],
#        [-1.0030227 ,  0.47123078],
#        [-0.46939486, -0.20915591],
#        [ 0.77573677,  0.01763965],
#        [ 1.48724056,  0.14363719],
#        [ 1.30936461,  0.24443522],
#        [ 0.3310469 ,  0.14363719],
#        [ 0.3310469 , -0.48635049],
#        [-0.91408473,  1.85720367],
#        [ 0.95361272,  1.32801403],
#        [-0.64727081, -0.81394408],
#        [-1.80346446, -0.33515344],
#        [-0.64727081,  0.24443522],
#        [ 0.41998488,  0.47123078],
#        [-0.20258094,  0.24443522],
#        [-0.82514675, -0.10835788],
#        [ 0.59786082,  0.39563226],
#        [ 0.77573677, -0.25955492],
#        [-0.20258094,  0.44603128],
#        [ 1.04255069,  0.72322585],
#        [ 1.48724056, -0.83914359],
#        [ 1.22042664, -0.91474211],
#        [-0.73620878, -1.41873225],
#        [ 0.41998488, -0.15875689],
#        [ 1.93193043,  1.10121846],
#        [-1.71452649, -1.19193669],
#        [-2.15921636,  2.78958544],
#        [ 0.15317095, -0.48635049],
#        [-0.73620878,  1.35321353],
#        [-1.71452649, -0.56194901],
#        [-1.0030227 ,  1.17681698],
#        [ 0.06423298,  0.67282684],
#        [ 0.15317095,  0.84922339],
#        [-1.09196068, -1.77152535],
#        [ 0.15317095,  0.24443522],
#        [ 1.84299245, -1.09113866],
#        [-1.09196068, -0.03275936],
#        [-0.91408473, -1.54472979],
#        [ 0.95361272, -1.46913127],
#        [-0.73620878,  0.14363719],
#        [-0.20258094,  0.5216298 ],
#        [ 0.15317095, -1.04073964],
#        [ 0.6867988 ,  0.79882438]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.39830258,  0.8996224 ],
#        [-0.11364297,  1.10121846],
#        [ 0.50892285,  0.95002142],
#        [-1.0030227 ,  1.02561994],
#        [ 1.39830258, -1.54472979],
#        [ 0.50892285, -0.81394408],
#        [ 0.86467474, -0.66274704],
#        [ 0.6867988 ,  1.50441058],
#        [ 2.28768232, -0.05795887],
#        [-0.91408473,  0.82402388]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 1, 0, 1, 1, 1, 1, 1, 0])

# %%
y_test
# Out:
# 91    1
# 85    1
# 38    1
# 34    0
# 44    1
# 79    1
# 66    1
# 97    1
# 69    1
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
# %pip install mlxtend
# Out:
# Collecting mlxtendNote: you may need to restart the kernel to use updated packages.
#
#   Obtaining dependency information for mlxtend from https://files.pythonhosted.org/packages/4c/43/2fc7f76c8891aef148901f1ba3dee65c1cbac00a85ae5ee0dabc2b861256/mlxtend-0.23.4-py3-none-any.whl.metadata
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.3.0)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (2.3.0)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.7.0)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (3.10.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prajyot upadhye\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\prajyot upadhye\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.4 MB 991.0 kB/s eta 0:00:02
#    ------- -------------------------------- 0.3/1.4 MB 3.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.4 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.4 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 1.2/1.4 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  1.4/1.4 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 4.8 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
# %pip install pickel
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement pickel (from versions: none)
# ERROR: No matching distribution found for pickel
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
